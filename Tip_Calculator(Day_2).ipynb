# %% [markdown]
# <a href="https://colab.research.google.com/github/Chosencodes/100-Days-Of-Python/blob/main/Tip_Calculator(Day_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing_extensions import final
print("Welcome to the Tip Calculator")

bill = float(input("What was the total bill $ ? "))
percent = int(input("How much tip would you like to give? 10, 12, 0r 15? "))
people = int(input("How many people to split the bill? "))

percentage = percent / 100
bill_percent = bill * percentage + bill
split = bill_percent / people
final_bill = round(split, 2)

print(f"Each person should pay: {final_bill}")
# Out:
# Welcome to the Tip Calculator
# What was the total bill $ ? 150
# How much tip would you like to give? 10, 12, 0r 15? 12
# How many people to split the bill? 5
# Each person should pay: 33.6
