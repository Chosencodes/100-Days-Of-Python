# %% [markdown]
# <a href="https://colab.research.google.com/github/Chosencodes/100-Days-Of-Python/blob/main/Exercise(Day_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Simple Anatomy Quiz**

# %%
print("Welcome to the Anatomy Quiz")
# Out:
# Welcome to the Anatomy Quiz

# %%
name = input("What is your name\n").title()
# Out:
# What is your name
# chosen

# %%
question_1 = input("What is the largest internal organ\n").title()
question_2 = input("What is the lagest bone in the upper limb\n").title()
question_3 = input("What organ pumps blood around the body\n").title()
# Out:
# What is the largest internal organ
# liver
# What is the lagest bone in the upper limb
# humerus
# What organ pumps blood around the body
# heart

# %%
print(f"Hello {name}!")

print("You answered:")

print("1.",question_1)

print("2.",question_2)

print("3.",question_3)
# Out:
# Hello Chosen!
# You answered:
# 1. Liver
# 2. Humerus
# 3. Heart
