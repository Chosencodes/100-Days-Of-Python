# %% [markdown]
# <a href="https://colab.research.google.com/github/Chosencodes/100-Days-Of-Python/blob/main/Treasure_Island.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Traseure Island")
print("Your mission is to find the treasure.")
# Out:
# Welcome to Traseure Island
# Your mission is to find the treasure.

# %%
crossroad = input(" You're at a crossroad. Where do you want to go? Type 'left' or 'right'.").lower()
