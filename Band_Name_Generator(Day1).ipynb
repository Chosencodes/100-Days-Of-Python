# %% [markdown]
# <a href="https://colab.research.google.com/github/Chosencodes/100-Days-Of-Python/blob/main/Band_Name_Generator(Day1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to the Band Name Generator")

city = input("What's the name of the city you grew up in?\n")
print("city")
pet = input("What's your pets's name?\n")
print(pet)
print("Your band name could be: " + city + pet)
# Out:
# Welcome to the Band Name Generator
# What's the name of the city you grew up in?
# benin
# city
# What's your pets's name?
# sparrow
# sparrow
# Your band name could be:beninsparrow
